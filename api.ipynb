# %%
# %pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.6.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.0-py3-none-any.whl (131 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 urllib3-2.6.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\MILENA\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

API_KEY="59fb1bba7ba542eb96f81336250612"
city="Warszawa"

url = "http://api.weatherapi.com/v1/current.json?key=185c2613c1a74951877205217241911&q=Warszawa&aqi=yes"

response= requests.get(url)
response = response.json()

print(response)
# Out:
# {'location': {'name': 'Warszawa', 'region': '', 'country': 'Poland', 'lat': 52.25, 'lon': 21.0, 'tz_id': 'Europe/Warsaw', 'localtime_epoch': 1765011947, 'localtime': '2025-12-06 10:05'}, 'current': {'last_updated_epoch': 1765011600, 'last_updated': '2025-12-06 10:00', 'temp_c': 7.1, 'temp_f': 44.8, 'is_day': 1, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png', 'code': 1009}, 'wind_mph': 7.6, 'wind_kph': 12.2, 'wind_degree': 143, 'wind_dir': 'SE', 'pressure_mb': 1016.0, 'pressure_in': 30.0, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 87, 'cloud': 75, 'feelslike_c': 4.8, 'feelslike_f': 40.6, 'windchill_c': 2.7, 'windchill_f': 36.8, 'heatindex_c': 5.4, 'heatindex_f': 41.7, 'dewpoint_c': 2.9, 'dewpoint_f': 37.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.2, 'gust_mph': 10.8, 'gust_kph': 17.4, 'air_quality': {'co': 217.85, 'no2': 15.55, 'o3': 19.0, 'so2': 10.95, 'pm2_5': 17.05, 'pm10': 19.35, 'us-epa-index': 2, 'gb-defra-index': 2}}}

# %%
import requests

API_KEY="59fb1bba7ba542eb96f81336250612"
city="Warszawa"

url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={city}&aqi=yes"

response= requests.get(url)
response = response.json()

print(f"Temperatura dla miasta {city} wynosi {response['current']['temp_c']} C")

print(f"Ciśnienie dla miasta {city} wynosi {response['current']['pressure_mb']}")

print(f"Wilgotność w mieście {city} wynosi {response['current']['humidity']} %")
# Out:
# Temperatura dla miasta Warszawa wynosi 7.4 C
# Ciśnienie dla miasta Warszawa wynosi 1016.0
# Wilgotność w mieście Warszawa wynosi 87 %

# %%
import requests

API_KEY="59fb1bba7ba542eb96f81336250612"
city = input("Podaj miasto, dla którego chcesz sprawdzić pogodę")

url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={city}&aqi=yes"

response= requests.get(url)
response = response.json()

print(f"Temperatura dla miasta {city} wynosi {response['current']['temp_c']} C")
print(f"Ciśnienie dla miasta {city} wynosi {response['current']['pressure_mb']} hPa")
print(f"Wilgotność dla miasta {city} wynosi {response['current']['humidity']} %")

if response['current']['condition']['text'] == 'Sunny':
    print(f"Warunki pogodowe dla {city}: Słonecznie")
else:
    print(f"Warunki pogodowe dla {city}: Nie jest słonecznie")

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined

# %%
print(response) 

# Jeżeli użytkownik wybierze opcję 4 to dodajemy też informację o pyłach PM10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(response)
#       3 # Jeżeli użytkownik wybierze opcję 4 to dodajemy też informację o pyłach PM10
#
# NameError: name 'response' is not defined

# %%
# %pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script unidecode.exe is installed in 'c:\Users\MILENA\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from unidecode import unidecode
miasto = "Łódź"
unidecode(miasto)
# Out:
# 'Lodz'
